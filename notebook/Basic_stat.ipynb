# %% [markdown]
# ## Task_1 Exploratory data Analysis(EDA)

# %%
import pandas as pd
import sys
sys.path.insert(0, 'D:/10 A KAI 2/week 3/Insurance_Claim_Analysis/')

# %%
from scripts.Basic_stat import InsuranceBasicStast

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', sep='|')
# Out:
# C:\Users\marta\AppData\Local\Temp\ipykernel_14452\1274272554.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.txt', sep='|')

# %%
df['Province'].value_counts()
# Out:
# Province
# Gauteng          393865
# Western Cape     170796
# KwaZulu-Natal    169781
# North West       143287
# Mpumalanga        52718
# Eastern Cape      30336
# Limpopo           24836
# Free State         8099
# Northern Cape      6380
# Name: count, dtype: int64

# %%
import numpy as np
df['Gender'] = df['Gender'].replace({'Not specified': np.nan})

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(950526)

# %%
basic = InsuranceBasicStast(df)
# Out:
# 2024-11-16 11:21:08,259 - INFO - Initialized InsuranceBasicStast with dataframe of shape (1000098, 52)

# %%
basic.Describtive_ana()
# Out:
# 2024-11-16 11:21:08,292 - INFO - Entering Descriptive Analysis
# 2024-11-16 11:21:09,334 - INFO - Exiting Descriptive Analysis
#                               count         mean          std         min  \
# UnderwrittenCoverID       1000098.0    104817.55     63293.71        1.00
# PolicyID                  1000098.0      7956.68      5290.04       14.00
# PostalCode                1000098.0      3020.60      2649.85        1.00
# mmcode                     999546.0  54877704.02  13603805.34  4041200.00
# RegistrationYear          1000098.0      2010.23         3.26     1987.00
# Cylinders                  999546.0         4.05         0.29        0.00
# cubiccapacity              999546.0      2466.74       442.80        0.00
# kilowatts                  999546.0        97.21        19.39        0.00
# NumberOfDoors              999546.0         4.02         0.47        0.00
# CustomValueEstimate        220456.0    225531.13    564515.75    20000.00
# ...

# %% [markdown]
# ### Columns variability

# %%
basic.variability_spcf_col()
# Out:
# 2024-11-16 11:21:09,349 - INFO - Calculating variability for specific columns
# 2024-11-16 11:21:09,677 - INFO - Exiting variability_spcf_col
#                               count       mean         std       min      25%  \
# TotalPremium              1000098.0      61.91      230.28   -782.58     0.00
# TotalClaims               1000098.0      64.86     2384.07 -12002.41     0.00
# CalculatedPremiumPerTerm  1000098.0     117.88      399.70      0.00     3.22
# SumInsured                1000098.0  604172.73  1508331.84      0.01  5000.00
#
#                               50%        75%          max
# TotalPremium                 2.18      21.93     65282.60
# TotalClaims                  0.00       0.00    393092.11
# CalculatedPremiumPerTerm     8.44      90.00     74422.17
# SumInsured                7500.00  250000.00  12636200.00

# %% [markdown]
# ### Datatype of the original dataset

# %%
basic.data_types()
# Out:
# 2024-11-16 11:21:09,740 - INFO - Getting data types and missing data
# 2024-11-16 11:21:09,756 - INFO - Exiting data_types
#                                             Column data_typs
# bodytype                                  bodytype    object
# Product                                    Product    object
# Model                                        Model    object
# Section                                    Section    object
# CoverGroup                              CoverGroup    object
# CoverType                                CoverType    object
# CoverCategory                        CoverCategory    object
# ExcessSelected                      ExcessSelected    object
# VehicleIntroDate                  VehicleIntroDate    object
# AlarmImmobiliser                  AlarmImmobiliser    object
# TrackingDevice                      TrackingDevice    object
# CapitalOutstanding              CapitalOutstanding    object
# ...

# %% [markdown]
# ### Missing Percentage of each columns

# %%
basic.missing_percentage()
# Out:
# 2024-11-16 11:21:09,811 - INFO - Calculating missing percentage
# 2024-11-16 11:21:12,398 - INFO - Exiting missing_percentage
#                                             Column  Missing Percentage
# NumberOfVehiclesInFleet    NumberOfVehiclesInFleet          100.000000
# CrossBorder                            CrossBorder           99.930207
# Gender                                      Gender           95.043286
# CustomValueEstimate            CustomValueEstimate           77.956560
# Rebuilt                                    Rebuilt           64.183810
# WrittenOff                              WrittenOff           64.183810
# Converted                                Converted           64.183810
# NewVehicle                              NewVehicle           15.327998
# Bank                                          Bank           14.594670
# AccountType                            AccountType            4.022806
# ...

# %% [markdown]
# ### Univariant Analysis

# %% [markdown]
# #### Univariant analysis for catagorical variables

# %%
basic.univariant_catagor_attri()
# Out:
# 2024-11-16 11:21:12,416 - INFO - Generating univariate categorical attribute plots
# 2024-11-16 11:21:12,429 - INFO - Renaming variable values
# 2024-11-16 11:21:39,385 - INFO - Exiting univariant_catagor_attri

# %% [markdown]
# ### General observation
# * The data is dominated by passenger vehicles, with a significant presence of commercial vehicle types as well.
# * Monthly term frequency policies vastly outnumber annual policies.
# * New vehicle policies make up the majority of the portfolio.
# * The customer base is heavily skewed towards male policyholders and majority of the gender is not specifed on the datset.
# * not_specfied  constitute the largest marital status segment.
# * The 'Mr' title is the most prevalent, reflecting the male-centric nature of the customer base.

# %% [markdown]
# #### Univariant Analysis for numerci columns

# %%
basic.univariate_analysis_plot()
# Out:
# 2024-11-16 11:21:39,416 - INFO - Generating univariate analysis plots for numeric
# 2024-11-16 11:21:39,416 - INFO - Filling numeric columns with mean values
# 2024-11-16 11:21:39,557 - INFO - Exiting fill_numeri_by_mean
# 2024-11-16 11:22:24,538 - INFO - Exiting univariate_analysis_plot

# %% [markdown]
# ### Key insight
# 1. PostalCode Distribution: Diverse geographic spread with a few dominant postal codes.
# 2. Kilowatts Distribution: Bimodal pattern suggesting two distinct customer segments.
# 3. SumInsured Distribution: Heavily right-skewed, with a concentration of lower insured amounts.
# 4. CalculatedPremiumPerTerm Distribution: Heavily left-skewed, indicating a large number of affordable policies.
# 5. TotalClaims Distribution: Right-skewed, reflecting the typical variability in claims behavior.

# %%
basic.bivariate_analysis()
# Out:
# 2024-11-16 11:22:24,554 - INFO - Performing bivariate analysis
# 2024-11-16 11:22:24,554 - INFO - Filling numeric columns with mean values
# 2024-11-16 11:22:24,601 - INFO - Exiting fill_numeri_by_mean
# 2024-11-16 11:22:25,069 - INFO - Exiting bivariate_analysis

# %% [markdown]
# ### Concise Insights from the Correlation Heatmap:
# 1. Weak Positive Correlation between TotalClaims and TotalPremium (0.12)
# 2. Negligible Correlation between TotalClaims and PostalCode (0.00041)
# 3. Negligible Correlation between TotalPremium and PostalCode (0.00074)
# 4. These insights suggest that the total claims and total premium amounts are not strongly influenced by the * geographic location represented by the postal code, while there is a slight positive relationship between the total claims and total premium.

# %%
basic.bivariate_scatter_plot()
# Out:
# 2024-11-16 11:22:25,085 - INFO - Generating bivariate scatter plot
# 2024-11-16 11:22:25,085 - INFO - Filling numeric columns with mean values
# 2024-11-16 11:22:25,132 - INFO - Exiting fill_numeri_by_mean
# 2024-11-16 11:23:20,294 - INFO - Exiting bivariate_scatter_plot

# %% [markdown]
# ### Concise Insights:
# 1. Weak relationship between Total Premium and Total Claims
# 2. Lack of clear clustering by Postal Code
# 3. Presence of outliers and extreme values

# %%
basic.analyze_insurance_trends()
# Out:
# 2024-11-16 11:23:20,299 - INFO - Analyzing insurance trends
# 2024-11-16 11:23:29,228 - INFO - Exiting analyze_insurance_trends

# %% [markdown]
# #### Concise Insights on Insurance Cover Types:
# 1. Dominant Cover Types: Windscreen, Own Damage, and Third Party Liability remain the most prevalent.
# 2. Emerging Cover Types: Baggage/Luggage Cover and Asset Value Protection are gaining prominence.
# 3. Declining Cover Types: Cleaning and Polishing, and Factory Fitted Sound and Other Electronic Equipment show decreasing popularity.
# 4. Specialized Cover Types: Excess Water, Deposit Cover, and Cash Only maintain relatively stable but lower counts.
# 5. Seasonal/Periodic Cover Types: Taking Liability Only and Third Party, Fire and Theft exhibit fluctuating patterns.

# %%
basic.outlier_all_num_co()
# Out:
# 2024-11-16 11:23:29,241 - INFO - Checking for outliers in numeric columns
# 2024-11-16 11:23:48,806 - INFO - Exiting outlier_all_num_co

# %% [markdown]
# ### Concise Insights from the Box Plots:
# 1. Wide Range and Outliers in Total Premium and Calculated Premium Per Term
# 2. Highly Skewed Distribution of Total Claims with Long Tail
# 3. Most Policies for Vehicles with Around 4 Doors
# 4. Bimodal Distribution of Kilowatts Suggesting Two Segments
# 5. Diverse Range of Vehicle Cubic Capacity and Cylinder Counts

# %%
basic.plot_Vehicle_premium()
# Out:
# 2024-11-16 11:23:48,823 - INFO - Plotting vehicle premium distribution
# D:\10 A KAI 2/week 3/Insurance_Claim_Analysis\scripts\Basic_stat.py:164: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x='VehicleType', y='TotalPremium', palette='Set2')
# D:\10 A KAI 2/week 3/Insurance_Claim_Analysis\scripts\Basic_stat.py:175: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=self.df, x='VehicleType', y='TotalPremium', hue='Province', ci=None, palette='pastel')
# 2024-11-16 11:23:58,435 - INFO - Exiting plot_Vehicle_premium

# %% [markdown]
# ### General Insights:
# 1. Regional Trends: The data highlights distinct regional patterns in insurance claims, suggesting the need to consider geographical factors when analyzing and managing claims.
# 2. Vehicle-Specific Factors: The variations in average claims across vehicle types point to the importance of understanding the unique risk profiles and cost dynamics associated with different vehicle categories.
# 3. Portfolio Optimization: The distribution of total claims by vehicle type provides high-level insights that can inform portfolio management strategies, resource allocation, and risk mitigation efforts.
# 4. Further Analysis: These visualizations serve as a starting point for deeper analysis to uncover the root causes behind the observed patterns and support data-driven decision-making in the insurance sector.

# %%
basic.plot_Vehicle_TotalClaims()
# Out:
# 2024-11-16 11:23:58,451 - INFO - Plotting vehicle total claims distribution
# D:\10 A KAI 2/week 3/Insurance_Claim_Analysis\scripts\Basic_stat.py:192: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x='VehicleType', y='TotalClaims', palette='Set2')
# D:\10 A KAI 2/week 3/Insurance_Claim_Analysis\scripts\Basic_stat.py:203: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=self.df, x='VehicleType', y='TotalClaims', hue='Province', ci=None, palette='pastel')
# 2024-11-16 11:24:07,988 - INFO - Exiting plot_Vehicle_TotalClaims

# %% [markdown]
# ### Total Claims Distribution by Vehicle Type:
# * Passenger vehicles account for the largest share of total claims
# * Commercial vehicle categories (medium, heavy, light) follow in decreasing order
# * Bus category has a relatively small share of total claims compared to other vehicle types
# * This distribution provides high-level insights into the composition of the overall claims portfolio, which can inform strategic decisions around resource allocation, risk management, and product development.
