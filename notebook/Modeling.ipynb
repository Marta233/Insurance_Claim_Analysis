# %%
import pandas as pd
import sys
sys.path.insert(0, 'D:/10 A KAI 2/week 3/Insurance_Claim_Analysis/')

# %%
from scripts.Preprocess import DataPreprocessor
from scripts.Basic_stat import InsuranceBasicStast
from scripts.modelBuilding import InsuranceModeling 
from scripts.insurancpostalcode import InsuranceByPostalCode

# %%
df = pd.read_csv('../data/MachineLearningRating_v3.txt', sep='|')
# Out:
# C:\Users\marta\AppData\Local\Temp\ipykernel_14672\1274272554.py:1: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/MachineLearningRating_v3.txt', sep='|')

# %%
preprocessor = DataPreprocessor(df)
basic = InsuranceBasicStast(df)
model = InsuranceModeling(df)
model2= InsuranceByPostalCode(df)

# %%
preprocessor = DataPreprocessor(df)  # Pass the DataFrame to the preprocessor

# %%
value_mappings = preprocessor.run_preprocessing()  # Handle missing data and encode categorical data
processed_data = preprocessor.get_processed_data()  # Get the processed DataFrame
# Out:
# Dropped columns with > 50% missing data: ['MaritalStatus', 'CustomValueEstimate', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet']
# Preprocessing completed. Missing values handled.
# D:\10 A KAI 2/week 3/Insurance_Claim_Analysis\scripts\Preprocess.py:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.df['VehicleIntroDate'] = pd.to_datetime(self.df['VehicleIntroDate'], errors='coerce')
# Feature engineering completed.
# Categorical data encoded using label encoding.
# Preprocessing pipeline completed.

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'IsVATRegistered', 'Citizenship',
#        'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'Gender',
#        'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone',
#        'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make',
#        'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype',
#        'NumberOfDoors', 'AlarmImmobiliser', 'TrackingDevice',
#        'CapitalOutstanding', 'NewVehicle', 'SumInsured', 'TermFrequency',
#        'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory',
#        'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass',
#        'StatutoryRiskType', 'TotalPremium', 'TotalClaims', 'TransactionYear',
#        'TransactionMonthNum', 'TransactionDay', 'VehicleIntroYear',
#        'VehicleIntroMonth', 'VehicleAge', 'PremiumPerClaim', 'IsNewVehicle'],
#       dtype='object')

# %%
basic.missing_percentage()
# Out:
#                                             Column  Missing Percentage
# UnderwrittenCoverID            UnderwrittenCoverID                 0.0
# PolicyID                                  PolicyID                 0.0
# IsVATRegistered                    IsVATRegistered                 0.0
# Citizenship                            Citizenship                 0.0
# LegalType                                LegalType                 0.0
# Title                                        Title                 0.0
# Language                                  Language                 0.0
# Bank                                          Bank                 0.0
# AccountType                            AccountType                 0.0
# Gender                                      Gender                 0.0
# Country                                    Country                 0.0
# Province                                  Province                 0.0
# ...

# %%
df.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'IsVATRegistered', 'Citizenship',
#        'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'Gender',
#        'Country', 'Province', 'PostalCode', 'MainCrestaZone', 'SubCrestaZone',
#        'ItemType', 'mmcode', 'VehicleType', 'RegistrationYear', 'make',
#        'Model', 'Cylinders', 'cubiccapacity', 'kilowatts', 'bodytype',
#        'NumberOfDoors', 'AlarmImmobiliser', 'TrackingDevice',
#        'CapitalOutstanding', 'NewVehicle', 'SumInsured', 'TermFrequency',
#        'CalculatedPremiumPerTerm', 'ExcessSelected', 'CoverCategory',
#        'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass',
#        'StatutoryRiskType', 'TotalPremium', 'TotalClaims', 'TransactionYear',
#        'TransactionMonthNum', 'TransactionDay', 'VehicleIntroYear',
#        'VehicleIntroMonth', 'VehicleAge', 'PremiumPerClaim', 'IsNewVehicle'],
#       dtype='object')

# %%
model2.fit_linear_regression_per_PostalCode()
# Out:
# PostalCode 1459.0 - R^2 Score: 1.0
# PostalCode 1513.0 - R^2 Score: 1.0
# PostalCode 1619.0 - R^2 Score: 0.9923933896490046
# PostalCode 1625.0 - R^2 Score: 0.0
# PostalCode 1629.0 - R^2 Score: 1.0
# PostalCode 1852.0 - R^2 Score: 0.9378365563397449
# PostalCode 1982.0 - R^2 Score: 0.0
# PostalCode 2007.0 - R^2 Score: 1.0
# PostalCode 2066.0 - R^2 Score: 0.0
# PostalCode 4093.0 - R^2 Score: 0.0765670047966841
# PostalCode 2000.0 - R^2 Score: 0.6219873838649665
# PostalCode 1577.0 - R^2 Score: 1.0
# PostalCode 1610.0 - R^2 Score: 0.0
# PostalCode 2410.0 - R^2 Score: -2.05728284505955
# PostalCode 6200.0 - R^2 Score: 0.0
# PostalCode 122.0 - R^2 Score: 0.21140518959468002
# PostalCode 1520.0 - R^2 Score: 0.0
# PostalCode 1709.0 - R^2 Score: -11.773204978526147
# PostalCode 1739.0 - R^2 Score: -19.481735143365672
# PostalCode 4000.0 - R^2 Score: 0.6209336594514316
# PostalCode 4066.0 - R^2 Score: 0.0
# PostalCode 4091.0 - R^2 Score: -0.2725900820359486
# ...

# %%
# model2.plot_predictions_vs_actuals_all(model_dict)
# model2.plot_residuals_all(model_dict)
# model2.plot_feature_importance_all(model_dict, df.drop(['TotalClaims', 'PostalCode'], axis=1).columns)

# %%
model.run_linear_regression()  # Run Linear Regression
# Out:
# 2024/11/19 08:02:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024-11-19 08:02:44,111 - INFO - Linear Regression: RMSE = 0.7174, R² = 0.0108

# %%
model.run_random_forest()      # Run Random Forest
# Out:
# 2024-11-19 08:08:29,957 - INFO - Random Forest fitting time: 338.23 seconds
# 2024/11/19 08:09:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024-11-19 08:09:45,291 - INFO - Random Forest: RMSE = 0.7223, R² = -0.0029

# %%
model.run_xgboost()            # Run XGBoost
# Out:
# d:\10 A KAI 2\week 3\Insurance_Claim_Analysis\myenv\Lib\site-packages\xgboost\core.py:158: UserWarning: [08:10:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
# 2024/11/19 08:10:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024-11-19 08:10:06,701 - INFO - XGBoost: RMSE = 0.7256, R² = -0.0120

# %%
model.display_results_comparison()  # Display comparison table
# Out:
# Model Comparison:
#                Model      RMSE        R²
# 0  Linear Regression  0.717372  0.010775
# 1      Random Forest  0.722299 -0.002860
# 2            XGBoost  0.725573 -0.011970
